# %%
import urllib3
urllib3.disable_warnings()

# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'reanalysis-oras5',
    {
        'product_type': 'operational',
        'vertical_resolution': 'all_levels',
        'variable': [
            'meridional_velocity', 'potential_temperature', 'zonal_velocity',
        ],
        'year': [
            '2020', '2021',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
        'format': 'tgz',
    },
    '/mnt/kingfast1TB/oras5_2019/oras5_2020_21.tar.gz')
# Out:
# /home/peter/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'cds.climate.copernicus.eu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2022-02-24 16:55:35,460 INFO Welcome to the CDS
# 2022-02-24 16:55:35,461 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-oras5
# /home/peter/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'cds.climate.copernicus.eu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2022-02-24 16:55:35,671 INFO Request is queued
# ...
