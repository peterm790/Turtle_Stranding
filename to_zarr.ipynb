# %%
import xarray as xr
import zarr
import glob

# %%
file = '/mnt/kingfast1TB/2020_ERA5_popular_surface.grb'

# %%
x = xr.open_mfdataset(file, engine="cfgrib")
# Out:
# skipping corrupted Message
# Traceback (most recent call last):
#   File "/home/peter/anaconda3/lib/python3.8/site-packages/cfgrib/messages.py", line 242, in __iter__
#     yield self.message_from_file(file, errors=self.errors)
#   File "/home/peter/anaconda3/lib/python3.8/site-packages/cfgrib/messages.py", line 257, in message_from_file
#     return self.message_class.from_file(file, offset, **kwargs)
#   File "/home/peter/anaconda3/lib/python3.8/site-packages/cfgrib/messages.py", line 91, in from_file
#     codes_id = eccodes.codes_grib_new_from_file(file)
#   File "/home/peter/anaconda3/lib/python3.8/site-packages/cfgrib/bindings.py", line 185, in codes_grib_new_from_file
#     retval = check_last(lib.codes_handle_new_from_file)(context, fileobj, product_kind)
#   File "/home/peter/anaconda3/lib/python3.8/site-packages/cfgrib/bindings.py", line 159, in wrapper
#     raise GribInternalError(code[0])
# cfgrib.bindings.GribInternalError: ('Wrong message length (-23).', -23)
# ...

# %%
x
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 6613, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 ...
#   * time        (time) datetime64[ns] 2020-01-01 ... 2020-10-07T12:00:00
#     step        timedelta64[ns] ...
#     surface     int64 ...
#   * latitude    (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  (time) datetime64[ns] dask.array<chunksize=(6613,), meta=np.ndarray>
# Data variables:
#     u10         (time, latitude, longitude) float32 dask.array<chunksize=(6613, 721, 1440), meta=np.ndarray>
#     v10         (time, latitude, longitude) float32 dask.array<chunksize=(6613, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
# ...

# %%
x = x.drop('meanSea')

# %%
x
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 8592, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 ...
#   * time        (time) datetime64[ns] 2021-01-01 ... 2021-12-30T23:00:00
#     step        timedelta64[ns] ...
#     surface     int64 ...
#   * latitude    (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  (time) datetime64[ns] dask.array<chunksize=(8592,), meta=np.ndarray>
# Data variables:
#     u10         (time, latitude, longitude) float32 dask.array<chunksize=(8592, 721, 1440), meta=np.ndarray>
#     v10         (time, latitude, longitude) float32 dask.array<chunksize=(8592, 721, 1440), meta=np.ndarray>
#     t2m         (time, latitude, longitude) float32 dask.array<chunksize=(8592, 721, 1440), meta=np.ndarray>
#     msl         (time, latitude, longitude) float32 dask.array<chunksize=(8592, 721, 1440), meta=np.ndarray>
# ...

# %%
x = x.chunk({'time': 100, 'latitude': 40, 'longitude': 40})

# %%
x_1 = x.sel(time = '2021-01-01')

# %%
x_1.to_zarr('/mnt/kingfast1TB/ERA5_zarr/2021_ERA5.zarr',mode = 'w',  compute = True)
